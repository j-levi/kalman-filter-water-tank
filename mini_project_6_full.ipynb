# %% [markdown]
# Page
# 4
# of 4
# Mini Project # 6 Due: Nov. 19/2025
# Consider the water tank system shown in the following figure. The tank has an input, a water
# tap, which can add water to the tank and increase the water level. Water level is measured by a
# level sensor.
# The goal is to use Kalman filter to estimate the level of the water in the tank using the noisy
# measurements coming from the level sensor. Assume that the dynamics and the measurements
# are modeled by the following equations:
# 𝑥(𝑛 + 1) = 𝐴 𝑥(𝑛) + 𝐵 𝑢(𝑛) + 𝜀𝑝
# 𝑦(𝑛) = 𝐶 𝑥(𝑛) + 𝜀𝑚
# Here, 𝑢(𝑛) is the input to the system. In Kalman estimation we have:
# 𝐾(𝑛) = 𝑃𝑛|𝑛−1𝐶𝑇 [ 𝐶𝑃𝑛|𝑛−1𝐶𝑇 + 𝑅 ]−1
# 𝑥𝑛|𝑛 = 𝑥𝑛|𝑛−1 + 𝐾(𝑛) [ 𝑦(𝑛) − 𝐶𝑥𝑛|𝑛−1 ]
# 𝑃𝑛|𝑛 = [ 𝐼 − 𝐾(𝑛) 𝐶 ]𝑃𝑛|𝑛−1
# 𝑥𝑛+1|𝑛 = 𝐴𝑥𝑛|𝑛 + 𝐵𝑢(𝑛 + 1)
# 𝑃𝑛+1|𝑛 = 𝐴𝑃𝑛|𝑛𝐴𝑇 + 𝑄
# Here 𝑄 and 𝑅 are the covariance matrices of the process and measurement noises.

# %%
# Code for this section

# %% [markdown]
# 1. Assume that the tap is not adding any water to the tank and the level of the water is 1.0.
# Also assume that 𝑥(𝑛) is the level of the water in the tank at time 𝑛.
# a. The system is static. What are 𝐴 and 𝑢(𝑛)?
# b. We have only one sensor directly measuring the water level. What is 𝐶 ?

# %%
# Code for this section

# %% [markdown]
# c. At the beginning, before making any measurement, we have no idea about the
# water level in the tank. So, we assume that 𝑥0|0 = 0.0. We also have no confidence
# in this initial point. So, let’s assume that 𝑃0|0 = 1,000.0. Since our
# state variable and measurement are scalars, noise covariance matrices are scalars:
# 𝑄 = 𝑞, 𝑅 = 𝑟.
# Given: 𝑞 = 0.0001, 𝑟 = 0.1, 𝑦(1) = 0.9.
# Use the Kalman filter to find the first estimation of the water level.

# %%
# Code for this section

# %% [markdown]
# d. Since we have very minimum confidence in our initial estimation of the water level
# use the Maximum likelihood theory to find your estimation of the water level and
# the related covariance matrix. Compare results with Kalman filter. Test with
# 𝑃0|0 = 10,000.

# %%
# Code for this section

# %% [markdown]
# e. Measurements:
# 𝑦(1) = 0.9, 𝑦(2) = 0.8, 𝑦(3) = 1.1, 𝑦(4) = 1.0, 𝑦(5) = 0.95, 𝑦(6) = 1.05, 𝑦(7) = 1.2,
# 𝑦(8) = 0.9, 𝑦(9) = 0.85, 𝑦(10) = 1.15.
# Use Kalman filter for 10 iterations. Plot the true value, all measurements, and Kalman
# estimations. Determine how long until estimates are within 5 percent of true level.

# %%
# Code for this section

# %% [markdown]
# 2. Now assume someone opens the tap. True water level increases by 0.1 per second:
# 𝑥(0)=0.0, 𝑥(1)=0.1, ..., 𝑥(15)=1.5.
# Measurements given.
# Run Kalman filter with static model and q=0.0001, r=0.1.
# Plot actual, measurements, estimated.
# Why is there biased error?

# %%
# Code for this section

# %% [markdown]
# 2(b). Increase uncertainty:
# Try q = 0.01, 0.1, 1.0.
# Run Kalman filter again.
# Plot all results together.
# Explain why larger q improves estimation.

# %%
# Code for this section

# %% [markdown]
# 3. Two-state model:
# x = [x1
#      x2]
# x1 = level, x2 = dx1/dt
# A = [[1, 1],
#      [0, 1]]
# u(n)=0
# C = [1 0]
# P0|0 = diag(1000,1000)
# Q = [[q/3, q/2],[q/2, q]]

# %%
# Code for this section

# %% [markdown]
# 3(a) Use q=0.0001 and run Kalman filter with earlier measurements. Plot actual, measured, estimated. Evaluate performance.

# %%
# Code for this section

# %% [markdown]
# 3(b) Tap closes at level 1.0 but model still assumes increasing. Can this two-state model tolerate the situation? Test it.

# %%
# Code for this section
