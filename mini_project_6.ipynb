# %% [markdown]
# # Mini Project #6 Instructions
#
# ## 1. Static Tank Case
#
# ### (a) System is static
# Describe what A and u(n) are when the tank level does not change and the tap adds no water.
#
# ### (b) Measurement matrix C
# State the value of C when the sensor measures the water level directly.
#
# ### (c) First Kalman update
# Given:
# x0|0 = 0
# P0|0 = 1000
# q = 0.0001
# r = 0.1
# y(1) = 0.9
# Compute:
# - K(1)
# - x1|1
# - P1|1
#
# ### (d) Maximum Likelihood estimation
# Compute the ML estimate of x using:
# - Prior variance P0|0
# - Measurement variance r
# Compare with Kalman update for:
# - P0|0 = 1000
# - P0|0 = 10000
#
# ### (e) Ten measurements
# Measurements:
# 0.9, 0.8, 1.1, 1.0, 0.95, 1.05, 1.2, 0.9, 0.85, 1.15
# Run Kalman filter for 10 iterations.
# Plot:
# - True value
# - Measurements
# - Kalman estimates
# Determine how many seconds until estimate is within 5 percent of true level.
#
# ---
#
# ## 2. Tank Increasing but Model Assumes Static
#
# ### (a) Wrong model assumption
# True levels:
# 0.0, 0.1, 0.2, ..., 1.5
# Measurements given in instructions.
# Run Kalman filter with:
# - x0|0 = 0
# - q = 0.0001
# - r = 0.1
# Plot actual, measured, estimated.
# Explain the bias.
#
# ### (b) Increasing uncertainty q
# Run again with q ∈ {0.01, 0.1, 1.0}.
# Plot all cases and compare.
# Explain why increasing q improves estimation.
#
# ---
#
# ## 3. Two-State Model (Position and Rate)
#
# ### Model
# x = [ x1
#       x2 ]
# A = [[1, dt],
#      [0, 1]]
# dt = 1
# C = [1 0]
# Q = [[q/3, q/2],
#      [q/2, q]]
# q = 0.0001
# P0|0 = diag(1000,1000)
#
# ### (a) Run Kalman filter
# Use earlier measurements.
# Plot actual, measured, estimated.
# Evaluate performance.
#
# ### (b) Tap closes at level 1.0
# Assume model still believes water is increasing.
# Test whether estimator adapts well and explain the behavior.
#
# ---
#
# ## Deliverables
# Use this notebook to complete all computations and plots.

# %%
# Your code goes here
